# %%
import pandas as pd
import numpy as np

base_path = r"C:\Users\T10002\Downloads\supply_chain_management\data\processed"

supplier_master_df = pd.read_csv(
    base_path + r"\supplier_master.csv"
)

supplier_component_df = pd.read_csv(
    base_path + r"\supplier_component.csv"
)

purchase_orders_df = pd.read_csv(
    base_path + r"\purchase_orders.csv"
)

print("Supplier Master:")
print(supplier_master_df.shape)
display(supplier_master_df.head())

print("\nSupplier Component:")
print(supplier_component_df.shape)
display(supplier_component_df.head())

print("\nPurchase Orders:")
print(purchase_orders_df.shape)
display(purchase_orders_df.head())
# Out:
# Supplier Master:
# (27, 10)
#   supplier_id            supplier_name     location component_category  \
# 0        S001    Battery Systems India   Tamil Nadu            Battery
# 1        S002  Advanced Energy Systems    Karnataka            Battery
# 2        S003     EV Cell Technologies      Gujarat            Battery
# 3        S004  PowerCell Manufacturing  Maharashtra            Battery
# 4        S005   Electric Drive Systems   Tamil Nadu         Powertrain
#
#    lead_time_days  unit_cost  monthly_capacity  quality_rating  \
# 0              15      85000             12000             4.5
# 1              18      88000             10000             4.3
# 2              25       4200            500000             4.2
# 3              22       4500            450000             4.4
# 4              20      42000              8000             4.4
#
#    reliability_score  status
# 0                 92  Active
# 1                 89  Active
# 2                 87  Active
# ...
